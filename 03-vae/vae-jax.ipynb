# %% [markdown]
# # Loading dataset

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# Process the image file
def preprocess(img):
    img = tf.cast(img, tf.float32) / 255.
    img = tf.pad(img, ((2, 2), (2, 2), (0, 0)), constant_values=0)
    return img

def get_dataset(num_epochs, batch_size):
    # Download Fashion MNIST dataset
    train_ds = tfds.load('fashion_mnist', split='train')
    test_ds = tfds.load('fashion_mnist', split='test')

    # Mapping images as tf tensors
    train_ds = train_ds.map(lambda sample: {'image': preprocess(sample['image']),
                                            'label': sample['label']})
    test_ds = test_ds.map(lambda sample: {'image': preprocess(sample['image']),
                                          'label': sample['label']})

    # TF dataloader
    train_ds = train_ds.repeat(num_epochs).shuffle(1024)
    train_ds = train_ds.batch(batch_size, drop_remainder=True).prefetch(1)
    test_ds = test_ds.shuffle(1024)
    test_ds = test_ds.batch(batch_size, drop_remainder=True).prefetch(1)

    return train_ds, test_ds

# %%
import math

input_shape = (32, 32, 1)
num_epochs = 50
batch_size = 100

train_ds, test_ds = get_dataset(num_epochs, batch_size)
assert train_ds.take(1).element_spec['image'].shape[1:] == input_shape

# %%
import matplotlib.pyplot as plt


def display(images, n=10, size=(8,6), cmap="gray_r", as_type="float32", save_to=None, style="seaborn-v0_8"):
    """
    Displays n random images from each one of the supplied arrays.
    """
    plt.style.use(style)

    if images.max() > 1.0:
        images = images / 255.0
    elif images.min() < 0.0:
        images = (images + 1.0) / 2.0


    plt.figure(figsize=size)
    for i in range(n):
        _ = plt.subplot(1, n, i + 1)
        img =  images[i]
        plt.imshow(img.astype(as_type), cmap=cmap)
        plt.axis("off")

    if save_to:
        plt.savefig(save_to)
        print(f"\nSaved to {save_to}")

    plt.show()


samples = next(train_ds.as_numpy_iterator())
display(samples['image'])
# Out:
# 2025-01-10 15:49:02.545458: W tensorflow/core/kernels/data/cache_dataset_ops.cc:914] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# # Define the model

# %%
dim_latent = 2

# %%
import functools as ft

compose = lambda *fs: ft.reduce(lambda f, g: lambda x: g(f(x)), fs)

# %%
import jax
import jax.numpy as jnp
from flax import nnx
import itertools as it
import typing as tp


# Reparameterization trick
def reparameterize(key, mean, logvar):
    std = jnp.exp(0.5 * logvar)
    eps = jax.random.normal(key, logvar.shape)
    return mean + eps * std

@nnx.vmap
def kl_divergence(mean, logvar):
    return - 0.5 * jnp.sum(1 + logvar - jnp.power(mean, 2) - jnp.exp(logvar))


class Loss(nnx.Variable):
    pass


class Encoder(nnx.Module):

    def __init__(self, dim_in: int, dim_out: int, *, activation: tp.Callable, rngs: nnx.Rngs):

        self.layers = [

            # -------  CNN  -----------
            # nnx.Conv(in_features=dim_in, out_features=32, kernel_size=(3,3), strides=(2,2), rngs=rngs),
            # activation,
            # nnx.Conv(in_features=32, out_features=64, kernel_size=(3,3), strides=(2,2), rngs=rngs),
            # activation,
            # nnx.Conv(in_features=64, out_features=128, kernel_size=(3,3), strides=(2,2), rngs=rngs),
            # activation,
            # lambda x: x.reshape(x.shape[0], -1),
            # nnx.Linear(in_features=2048, out_features=dim_out, rngs=rngs),
            # -------  END CNN  -----------

            # -------  MLP  -----------
            lambda x: x.reshape(x.shape[0], -1),  # flatten
            nnx.Linear(in_features=dim_in, out_features=512, rngs=rngs),
            activation,
            nnx.Linear(in_features=512, out_features=128, rngs=rngs),
            activation,
            nnx.Linear(in_features=128, out_features=dim_out, rngs=rngs)
            # -------  END MLP  -----------

        ]
        self.linear_mean = nnx.Linear(dim_out, dim_out, rngs=rngs)
        self.linear_logvar = nnx.Linear(dim_out, dim_out, rngs=rngs)
        self.rngs = rngs

    def __call__(self, x: jax.Array) -> jax.Array:
        x = compose(*it.chain(self.layers))(x)
        mean_x = self.linear_mean(x)
        logvar_x = self.linear_logvar(x)
        # std  = jnp.exp(logvar_x)

        key = self.rngs.noise()
        z = reparameterize(key, mean_x, logvar_x)
        self.kl_loss = Loss(kl_divergence(mean_x, logvar_x))
        return z

# %%
# import math
# encoder = Encoder(dim_in=math.prod(input_shape), dim_out=dim_latent, activation=nnx.relu, rngs=nnx.Rngs(0, noise=1))
# encoder = Encoder(dim_in=input_shape[-1], dim_out=dim_latent, activation=nnx.relu, rngs=nnx.Rngs(0, noise=1))
#
# encoder(jnp.ones([1, *input_shape])).shape

# %%
class Decoder(nnx.Module):

    def __init__(self, dim_in: int, dim_out: int, *, activation: tp.Callable, rngs: nnx.Rngs):

        self.layers = [

            # -------  CNN  -----------
            # nnx.Linear(in_features=dim_in, out_features=2048, rngs=rngs),
            # lambda x: x.reshape(x.shape[0], 4, 4, 128),
            # activation,
            # nnx.ConvTranspose(in_features=128, out_features=128, kernel_size=(3,3), strides=(2,2), rngs=rngs),
            # activation,
            # nnx.ConvTranspose(in_features=128, out_features=64, kernel_size=(3,3), strides=(2,2), rngs=rngs),
            # activation,
            # nnx.ConvTranspose(in_features=64, out_features=32, kernel_size=(3,3), strides=(2,2), rngs=rngs),
            # activation,
            # nnx.Conv(in_features=32, out_features=dim_out, kernel_size=(3,3), strides=1, rngs=rngs),
            # -------  END CNN  -----------

            # -------  MLP  -----------
            nnx.Linear(in_features=dim_in, out_features=128, rngs=rngs),
            activation,
            nnx.Linear(in_features=128, out_features=512, rngs=rngs),
            activation,
            nnx.Linear(in_features=512, out_features=dim_out, rngs=rngs),
            # -------  END MLP  -----------

        ]

    def __call__(self, x: jax.Array) -> jax.Array:
        return compose(*it.chain(self.layers))(x)

# %%
# import math
# decoder = Decoder(dim_in=dim_latent, dim_out=math.prod(input_shape), activation=nnx.relu, rngs=nnx.Rngs(0))
# decoder = Decoder(dim_in=dim_latent, dim_out=input_shape[-1], activation=nnx.relu, rngs=nnx.Rngs(0))
#
# decoder(jnp.ones([1, dim_latent])).shape

# %% [markdown]
# # Variational AutoEncoder

# %%
class VAE(nnx.Module):

    def __init__(self,
                 dim_in: int,
                 dim_emb: int,
                 output_shape: tp.Sequence[int],
                 *,
                 activation: tp.Callable,
                 rngs: nnx.Rngs):

        self.encoder = Encoder(dim_in, dim_emb, activation=activation, rngs=rngs)
        self.decoder = Decoder(dim_emb, dim_in, activation=activation, rngs=rngs)
        self.output_shape = output_shape

    def encode(self, x):
        return self.encoder(x)

    def decode(self, x):
        return self.decoder(x)

    def generate(self, x):
        logits = self.decode(x)
        logits = jnp.reshape(logits, (-1, *self.output_shape))
        return nnx.sigmoid(logits)

    def __call__(self, x: jax.Array) -> jax.Array:
        logits = compose(self.encode, self.decode)(x)
        logits = jnp.reshape(logits, (-1, *self.output_shape))
        return logits

# %%
model = VAE(dim_in=math.prod(input_shape), dim_emb=2, output_shape=input_shape, activation=nnx.tanh, rngs=nnx.Rngs(0, noise=1))
# model = VAE(dim_in=input_shape[-1], dim_emb=2, output_shape=input_shape, activation=nnx.tanh, rngs=nnx.Rngs(0, noise=1))

nnx.display(model)
# Out:
# WARNING:jax._src.xla_bridge:Platform 'METAL' is experimental and not all JAX functionality may be correctly supported!
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1736484542.818538 13767689 mps_client.cc:510] WARNING: JAX Apple GPU support is experimental and not all JAX functionality is correctly supported!
# I0000 00:00:1736484542.829024 13767689 service.cc:145] XLA service 0x1742b5b80 initialized for platform METAL (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1736484542.829033 13767689 service.cc:153]   StreamExecutor device (0): Metal, <undefined>
# I0000 00:00:1736484542.830481 13767689 mps_client.cc:406] Using Simple allocator.
# I0000 00:00:1736484542.830495 13767689 mps_client.cc:384] XLA backend will use up to 51539214336 bytes on device 0 for SimpleAllocator.
# Metal device set to: Apple M2 Max
#
# systemMemory: 64.00 GB
# maxCacheSize: 24.00 GB
#
# VAE(
#   encoder=Encoder(
#     layers=[<function Encoder.__init__.<locals>.<lambda> at 0x177f368e0>, Linear(
#       kernel=Param(
#         value=Array(shape=(1024, 512), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(512,), dtype=float32)
#       ),
#       in_features=1024,
#       out_features=512,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x176d55a80>,
#       bias_init=<function zeros at 0x15683eca0>,
#       dot_general=<function dot_general at 0x1561d87c0>
#     ), <PjitFunction of <function tanh at 0x15664a520>>, Linear(
#       kernel=Param(
#         value=Array(shape=(512, 128), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(128,), dtype=float32)
#       ),
#       in_features=512,
#       out_features=128,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x176d55a80>,
#       bias_init=<function zeros at 0x15683eca0>,
#       dot_general=<function dot_general at 0x1561d87c0>
#     ), <PjitFunction of <function tanh at 0x15664a520>>, Linear(
#       kernel=Param(
#         value=Array(shape=(128, 2), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(2,), dtype=float32)
#       ),
#       in_features=128,
#       out_features=2,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x176d55a80>,
#       bias_init=<function zeros at 0x15683eca0>,
#       dot_general=<function dot_general at 0x1561d87c0>
#     )],
#     linear_mean=Linear(
#       kernel=Param(
#         value=Array(shape=(2, 2), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(2,), dtype=float32)
#       ),
#       in_features=2,
#       out_features=2,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x176d55a80>,
#       bias_init=<function zeros at 0x15683eca0>,
#       dot_general=<function dot_general at 0x1561d87c0>
#     ),
#     linear_logvar=Linear(
#       kernel=Param(
#         value=Array(shape=(2, 2), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(2,), dtype=float32)
#       ),
#       in_features=2,
#       out_features=2,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x176d55a80>,
#       bias_init=<function zeros at 0x15683eca0>,
#       dot_general=<function dot_general at 0x1561d87c0>
#     ),
#     rngs=Rngs(
#       noise=RngStream(
#         key=RngKey(
#           value=Array((), dtype=key<fry>) overlaying:
#           [0 1],
#           tag='noise'
#         ),
#         count=RngCount(
#           value=Array(0, dtype=uint32),
#           tag='noise'
#         )
#       ),
#       default=RngStream(
#         key=RngKey(
#           value=Array((), dtype=key<fry>) overlaying:
#           [0 0],
#           tag='default'
#         ),
#         count=RngCount(
#           value=Array(16, dtype=uint32),
#           tag='default'
#         )
#       )
#     )
#   ),
#   decoder=Decoder(
#     layers=[Linear(
#       kernel=Param(
#         value=Array(shape=(2, 128), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(128,), dtype=float32)
#       ),
#       in_features=2,
#       out_features=128,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x176d55a80>,
#       bias_init=<function zeros at 0x15683eca0>,
#       dot_general=<function dot_general at 0x1561d87c0>
#     ), <PjitFunction of <function tanh at 0x15664a520>>, Linear(
#       kernel=Param(
#         value=Array(shape=(128, 512), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(512,), dtype=float32)
#       ),
#       in_features=128,
#       out_features=512,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x176d55a80>,
#       bias_init=<function zeros at 0x15683eca0>,
#       dot_general=<function dot_general at 0x1561d87c0>
#     ), <PjitFunction of <function tanh at 0x15664a520>>, Linear(
#       kernel=Param(
#         value=Array(shape=(512, 1024), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(1024,), dtype=float32)
#       ),
#       in_features=512,
#       out_features=1024,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x176d55a80>,
#       bias_init=<function zeros at 0x15683eca0>,
#       dot_general=<function dot_general at 0x1561d87c0>
#     )]
#   ),
#   output_shape=(32, 32, 1)
# )

# %%
import jax.numpy as jnp

model(jnp.ones([1, *input_shape])).shape
# Out:
# (1, 32, 32, 1)

# %% [markdown]
# # Optimizer

# %%
import optax

# lr_schedule = optax.warmup_cosine_decay_schedule(
#     init_value=0.0,
#     peak_value=1e-3,
#     warmup_steps=100,
#     decay_steps=500*len(train_ds),
#     end_value=1e-5
# )
# optimizer = nnx.Optimizer(
#     model,
#     optax.chain(
#         optax.clip(1.0),  # Clip gradients at 1
#         optax.adam(lr_schedule)
#     )
# )

learning_rate=1e-4
optimizer = nnx.Optimizer(model, optax.adam(learning_rate))

metric = nnx.metrics.Average()
nnx.display(metric)
# Out:
# Average(
#   argname='values',
#   total=MetricState(
#     value=Array(0., dtype=float32)
#   ),
#   count=MetricState(
#     value=Array(0, dtype=int32)
#   )
# )

# %% [markdown]
# # Define training steps

# %%
def loss_fn(model: VAE, batch: jax.Array):
    logits = model(batch["image"])
    losses = nnx.pop(model, Loss)
    kl_loss = jnp.mean(jnp.asarray(
        jax.tree_util.tree_leaves(losses)#), 0.0
    ))
    reconstruction_loss = jnp.mean(
        optax.sigmoid_binary_cross_entropy(logits, batch["image"])
    )
    loss = reconstruction_loss + 0.01 * kl_loss
    return loss

# %%
@nnx.jit
def train_step(model: VAE, optimizer: nnx.Optimizer, metric: nnx.Metric, batch: jax.Array):
    grad_fn = nnx.value_and_grad(loss_fn, has_aux=False)
    loss, grads = grad_fn(model, batch)
    metric.update(values=loss)
    optimizer.update(grads)

@nnx.jit
def eval_step(model: VAE, metric: nnx.Metric, batch: jax.Array):
    loss = loss_fn(model, batch)
    metric.update(values=loss)

# %% [markdown]
# # Train and evaluate the model

# %%
metric_history = {
    "train_loss": [],
    "test_loss": [],
}

num_steps_per_epoch = train_ds.cardinality() // num_epochs

for step, batch in enumerate(train_ds.as_numpy_iterator(), start=1):

    train_step(model, optimizer, metric, batch)

    if step % num_steps_per_epoch == 0:

        # Log the training metric.
        value = metric.compute()
        metric_history[f"train_loss"].append(value)  # Record the metric.
        metric.reset()  # Reset the metric for the test set.

        # Compute the metric on the test set after each training epoch.
        for test_batch in test_ds.as_numpy_iterator():
            eval_step(model, metric, test_batch)

        # Log the test metric.
        value = metric.compute()
        metric_history[f'test_loss'].append(value)
        metric.reset()  # Reset the metric for the next training epoch.

        print(
            f"[train] epoch: {step//num_steps_per_epoch}, "
            f"loss: {metric_history['train_loss'][-1]:.4f}",
        )

        print(
            f"[test] epoch: {step//num_steps_per_epoch}, "
            f"loss: {metric_history['test_loss'][-1]:.4f}"
            '\n'
        )
# Out:
# [train] epoch: 1, loss: 0.4169
# [test] epoch: 1, loss: 0.3821
#
# [train] epoch: 2, loss: 0.3729
# [test] epoch: 2, loss: 0.3681
#
# [train] epoch: 3, loss: 0.3633
# [test] epoch: 3, loss: 0.3607
#
# [train] epoch: 4, loss: 0.3580
# [test] epoch: 4, loss: 0.3565
#
# [train] epoch: 5, loss: 0.3541
# [test] epoch: 5, loss: 0.3532
#
# [train] epoch: 6, loss: 0.3505
# [test] epoch: 6, loss: 0.3492
#
# [train] epoch: 7, loss: 0.3468
# [test] epoch: 7, loss: 0.3454
#
# [train] epoch: 8, loss: 0.3431
# [test] epoch: 8, loss: 0.3417
#
# [train] epoch: 9, loss: 0.3385
# [test] epoch: 9, loss: 0.3374
#
# [train] epoch: 10, loss: 0.3346
# [test] epoch: 10, loss: 0.3340
#
# [train] epoch: 11, loss: 0.3312
# [test] epoch: 11, loss: 0.3307
#
# [train] epoch: 12, loss: 0.3279
# [test] epoch: 12, loss: 0.3276
#
# [train] epoch: 13, loss: 0.3250
# [test] epoch: 13, loss: 0.3249
#
# [train] epoch: 14, loss: 0.3225
# [test] epoch: 14, loss: 0.3227
#
# [train] epoch: 15, loss: 0.3208
# [test] epoch: 15, loss: 0.3215
#
# [train] epoch: 16, loss: 0.3194
# [test] epoch: 16, loss: 0.3206
#
# [train] epoch: 17, loss: 0.3186
# [test] epoch: 17, loss: 0.3194
#
# [train] epoch: 18, loss: 0.3175
# [test] epoch: 18, loss: 0.3185
#
# [train] epoch: 19, loss: 0.3167
# [test] epoch: 19, loss: 0.3179
#
# [train] epoch: 20, loss: 0.3158
# [test] epoch: 20, loss: 0.3166
#
# [train] epoch: 21, loss: 0.3147
# [test] epoch: 21, loss: 0.3158
#
# [train] epoch: 22, loss: 0.3138
# [test] epoch: 22, loss: 0.3151
#
# [train] epoch: 23, loss: 0.3129
# [test] epoch: 23, loss: 0.3139
#
# [train] epoch: 24, loss: 0.3115
# [test] epoch: 24, loss: 0.3126
#
# [train] epoch: 25, loss: 0.3104
# [test] epoch: 25, loss: 0.3112
#
# [train] epoch: 26, loss: 0.3098
# [test] epoch: 26, loss: 0.3114
#
# [train] epoch: 27, loss: 0.3091
# [test] epoch: 27, loss: 0.3100
#
# [train] epoch: 28, loss: 0.3087
# [test] epoch: 28, loss: 0.3101
#
# [train] epoch: 29, loss: 0.3081
# [test] epoch: 29, loss: 0.3095
#
# [train] epoch: 30, loss: 0.3075
# [test] epoch: 30, loss: 0.3088
#
# [train] epoch: 31, loss: 0.3072
# [test] epoch: 31, loss: 0.3085
#
# [train] epoch: 32, loss: 0.3069
# [test] epoch: 32, loss: 0.3081
#
# [train] epoch: 33, loss: 0.3064
# [test] epoch: 33, loss: 0.3079
#
# [train] epoch: 34, loss: 0.3060
# [test] epoch: 34, loss: 0.3073
#
# [train] epoch: 35, loss: 0.3059
# [test] epoch: 35, loss: 0.3071
#
# [train] epoch: 36, loss: 0.3056
# [test] epoch: 36, loss: 0.3070
#
# [train] epoch: 37, loss: 0.3053
# [test] epoch: 37, loss: 0.3067
#
# [train] epoch: 38, loss: 0.3050
# [test] epoch: 38, loss: 0.3063
#
# [train] epoch: 39, loss: 0.3050
# [test] epoch: 39, loss: 0.3064
#
# [train] epoch: 40, loss: 0.3046
# [test] epoch: 40, loss: 0.3062
#
# [train] epoch: 41, loss: 0.3043
# [test] epoch: 41, loss: 0.3058
#
# [train] epoch: 42, loss: 0.3039
# [test] epoch: 42, loss: 0.3055
#
# [train] epoch: 43, loss: 0.3037
# [test] epoch: 43, loss: 0.3056
#
# [train] epoch: 44, loss: 0.3036
# [test] epoch: 44, loss: 0.3053
#
# [train] epoch: 45, loss: 0.3033
# [test] epoch: 45, loss: 0.3049
#
# [train] epoch: 46, loss: 0.3033
# [test] epoch: 46, loss: 0.3048
#
# [train] epoch: 47, loss: 0.3029
# [test] epoch: 47, loss: 0.3047
#
# [train] epoch: 48, loss: 0.3029
# [test] epoch: 48, loss: 0.3043
#
# [train] epoch: 49, loss: 0.3027
# [test] epoch: 49, loss: 0.3042
#
# [train] epoch: 50, loss: 0.3025
# [test] epoch: 50, loss: 0.3041

# %%
import matplotlib.pyplot as plt  # Visualization

# Plot loss and accuracy in subplots
fig = plt.figure(figsize=(5.5, 5))
plt.title('Loss')
for dataset in ('train', 'test'):
    plt.plot(metric_history[f'{dataset}_loss'], label=f'{dataset}_loss')
fig.legend()
plt.show()

# %% [markdown]
# # Reconstruction

# %%
test_examples = test_batch['image']
display(test_examples)

# %%
reconstructions = nnx.sigmoid(model(test_examples))
display(reconstructions)

# %% [markdown]
# # Visualising the embedding space

# %%
embeddings = model.encode(test_batch["image"])
plt.figure(figsize=(5.5, 5.5))
plt.scatter(embeddings[:, 0], embeddings[:, 1], c="black", alpha=0.5, s=3)
plt.show()

# %% [markdown]
# # Reconstruction

# %%
import numpy as np


def get_samples(ds, num_samples=10):
    example_images = []; example_labels = []
    for i, samples in enumerate(test_ds.as_numpy_iterator()):
        example_images.append(samples["image"])
        example_labels.append(samples["label"])

        if i*batch_size >= n_to_predict:
            break
    return np.vstack(example_images)[:n_to_predict], np.hstack(example_labels)[:n_to_predict]

n_to_predict = 5_000
example_images, example_labels = get_samples(test_ds, num_samples=n_to_predict)

embeddings = model.encode(example_images)

# %%
embeddings = model.encode(example_images)

figsize = 6
plt.figure(figsize=(figsize, figsize*0.8))
plt.scatter(
    embeddings[:, 0],
    embeddings[:, 1],
    cmap="rainbow",
    c=example_labels,
    alpha=0.8,
    s=3,
)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Generating new images

# %%
mins, maxs = np.min(embeddings, axis=0), np.max(embeddings, axis=0)

# Sample some points in the latent space
grid_width, grid_height = (6, 2)
samples = np.random.uniform(
    mins, maxs, size=(grid_width * grid_height, dim_latent)
)

# %%
reconstructions = model.generate(samples).reshape(-1, *input_shape)
display(reconstructions)

# %%
# Draw a plot of...
figsize = 5.5
plt.figure(figsize=(figsize, figsize))

# ... the original embeddings ...
plt.scatter(embeddings[:, 0], embeddings[:, 1], c="black", alpha=0.5, s=2)

# ... and the newly generated points in the latent space
plt.scatter(samples[:, 0], samples[:, 1], c="#00B0F0", alpha=1, s=40)
plt.show()

# Add underneath a grid of the decoded images
fig = plt.figure(figsize=(figsize, grid_height))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_width * grid_height):
    ax = fig.add_subplot(grid_height, grid_width, i + 1)
    ax.axis("off")
    ax.text(
        0.5,
        -0.35,
        str(np.round(samples[i, :], 1)),
        fontsize=10,
        ha="center",
        transform=ax.transAxes,
    )
    ax.imshow(reconstructions[i, :, :], cmap="Greys")

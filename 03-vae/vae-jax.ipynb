# %% [markdown]
# # Loading dataset

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# Process the image file
def preprocess(img):
    img = tf.cast(img, tf.float32) / 255.
    img = tf.pad(img, ((2, 2), (2, 2), (0, 0)), constant_values=0)
    return img

def get_dataset(num_epochs, batch_size):
    """The Fashion MNIST dataset loader"""

    train_ds = tfds.load('fashion_mnist', split='train')
    test_ds = tfds.load('fashion_mnist', split='test')

    # Mapping images as tf tensors
    train_ds = train_ds.map(lambda sample: {'image': preprocess(sample['image']),
                                            'label': sample['label']})
    test_ds = test_ds.map(lambda sample: {'image': preprocess(sample['image']),
                                          'label': sample['label']})

    # TF dataloader
    train_ds = train_ds.repeat(num_epochs).shuffle(1024)
    train_ds = train_ds.batch(batch_size, drop_remainder=True).prefetch(1)
    test_ds = test_ds.shuffle(1024)
    test_ds = test_ds.batch(batch_size, drop_remainder=True).prefetch(1)

    return train_ds, test_ds

# %%
input_shape = (32, 32, 1)
num_epochs = 50
batch_size = 100

train_ds, test_ds = get_dataset(num_epochs, batch_size)
assert train_ds.take(1).element_spec['image'].shape[1:] == input_shape

# %%
import matplotlib.pyplot as plt


def display(images, n=10, size=(8,6), cmap="gray_r", as_type="float32", save_to=None, style="seaborn-v0_8"):
    """
    Displays n random images from each one of the supplied arrays.
    """
    plt.style.use(style)

    if images.max() > 1.0:
        images = images / 255.0
    elif images.min() < 0.0:
        images = (images + 1.0) / 2.0


    plt.figure(figsize=size)
    for i in range(n):
        _ = plt.subplot(1, n, i + 1)
        img =  images[i]
        plt.imshow(img.astype(as_type), cmap=cmap)
        plt.axis("off")

    if save_to:
        plt.savefig(save_to)
        print(f"\nSaved to {save_to}")

    plt.show()


samples = next(train_ds.as_numpy_iterator())
display(samples['image'])
# Out:
# 2025-01-13 17:47:21.091683: W tensorflow/core/kernels/data/cache_dataset_ops.cc:914] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# # Define the model

# %%
dim_latent = 2

# %%
import functools as ft

compose = lambda *fs: ft.reduce(lambda f, g: lambda x: g(f(x)), fs)  # function composition
mapply = lambda *fs: lambda x: (f(x) for f in fs)  # multple function application

# %%
import jax
import jax.numpy as jnp
from flax import nnx
import typing as tp


# Reparameterization trick
def reparameterize(key, mean, logvar):
    std = jnp.exp(0.5 * logvar)
    eps = jax.random.normal(key, logvar.shape)
    return mean + eps * std

@nnx.vmap
def kl_divergence(mean, logvar):
    return - 0.5 * jnp.sum(1 + logvar - jnp.power(mean, 2) - jnp.exp(logvar))


class Loss(nnx.Variable):
    pass


class Reparameterization(nnx.Module):

    def __init__(self, *, rngs: nnx.Rngs):
        self.rngs = rngs

    def __call__(self, mean: jax.Array, logvar: jax.Array):
        std = jnp.exp(0.5 * logvar)
        key = self.rngs()
        eps = jax.random.normal(key, logvar.shape)
        return mean + eps * std


class Encoder(nnx.Module):

    def __init__(self, dim_in: int, dim_out: int, *, activation: tp.Callable, rngs: nnx.Rngs):

        self.layers = [

            # -------  CNN  -----------
            # nnx.Conv(in_features=dim_in, out_features=32, kernel_size=(3,3), strides=(2,2), rngs=rngs),
            # activation,
            # nnx.Conv(in_features=32, out_features=64, kernel_size=(3,3), strides=(2,2), rngs=rngs),
            # activation,
            # nnx.Conv(in_features=64, out_features=128, kernel_size=(3,3), strides=(2,2), rngs=rngs),
            # activation,
            # lambda x: x.reshape(x.shape[0], -1),
            # nnx.Linear(in_features=2048, out_features=dim_out, rngs=rngs),
            # -------  END CNN  -----------

            # -------  MLP  -----------
            lambda x: x.reshape(x.shape[0], -1),  # flatten
            nnx.Linear(in_features=dim_in, out_features=512, rngs=rngs),
            activation,
            nnx.Linear(in_features=512, out_features=128, rngs=rngs),
            activation,
            nnx.Linear(in_features=128, out_features=dim_out, rngs=rngs)
            # -------  END MLP  -----------

        ]
        self.linear_mean = nnx.Linear(dim_out, dim_out, rngs=rngs)
        self.linear_logvar = nnx.Linear(dim_out, dim_out, rngs=rngs)
        self.reparameterize = Reparameterization(rngs=rngs.noise)

    def __call__(self, x: jax.Array) -> jax.Array:
        mean_x, logvar_x = compose(
            compose(*self.layers),
            mapply(self.linear_mean, self.linear_logvar)
        )(x)
        z =  self.reparameterize(mean_x, logvar_x)
        self.kl_loss = Loss(kl_divergence(mean_x, logvar_x))
        return z

# %%
# import math
# encoder = Encoder(dim_in=math.prod(input_shape), dim_out=dim_latent, activation=nnx.relu, rngs=nnx.Rngs(0, noise=1))
# encoder = Encoder(dim_in=input_shape[-1], dim_out=dim_latent, activation=nnx.relu, rngs=nnx.Rngs(0, noise=1))

# encoder(jnp.ones([batch_size, *input_shape])).shape

# %%
class Decoder(nnx.Module):

    def __init__(self, dim_in: int, dim_out: int, *, activation: tp.Callable, rngs: nnx.Rngs):

        self.layers = [

            # -------  CNN  -----------
            # nnx.Linear(in_features=dim_in, out_features=2048, rngs=rngs),
            # lambda x: x.reshape(x.shape[0], 4, 4, 128),
            # activation,
            # nnx.ConvTranspose(in_features=128, out_features=128, kernel_size=(3,3), strides=(2,2), rngs=rngs),
            # activation,
            # nnx.ConvTranspose(in_features=128, out_features=64, kernel_size=(3,3), strides=(2,2), rngs=rngs),
            # activation,
            # nnx.ConvTranspose(in_features=64, out_features=32, kernel_size=(3,3), strides=(2,2), rngs=rngs),
            # activation,
            # nnx.Conv(in_features=32, out_features=dim_out, kernel_size=(3,3), strides=1, rngs=rngs),
            # -------  END CNN  -----------

            # -------  MLP  -----------
            nnx.Linear(in_features=dim_in, out_features=128, rngs=rngs),
            activation,
            nnx.Linear(in_features=128, out_features=512, rngs=rngs),
            activation,
            nnx.Linear(in_features=512, out_features=dim_out, rngs=rngs),
            # -------  END MLP  -----------
        ]

    def __call__(self, x: jax.Array) -> jax.Array:
        return compose(*self.layers)(x)

# %%
# import math
# decoder = Decoder(dim_in=dim_latent, dim_out=math.prod(input_shape), activation=nnx.relu, rngs=nnx.Rngs(0))
# decoder = Decoder(dim_in=dim_latent, dim_out=input_shape[-1], activation=nnx.relu, rngs=nnx.Rngs(0))
#
# decoder(jnp.ones([1, dim_latent])).shape

# %% [markdown]
# # Variational AutoEncoder

# %%
class VAE(nnx.Module):

    def __init__(self,
                 dim_in: int,
                 dim_emb: int,
                 output_shape: tp.Sequence[int],
                 *,
                 activation: tp.Callable,
                 rngs: nnx.Rngs):

        self.encoder = Encoder(dim_in, dim_emb, activation=activation, rngs=rngs)
        self.decoder = Decoder(dim_emb, dim_in, activation=activation, rngs=rngs)
        self.output_shape = output_shape

    def encode(self, x):
        return self.encoder(x)

    def decode(self, x):
        return self.decoder(x)

    def generate(self, x):
        logits = self.decode(x)
        logits = jnp.reshape(logits, (-1, *self.output_shape))
        return nnx.sigmoid(logits)

    def __call__(self, x: jax.Array) -> jax.Array:
        logits = compose(self.encode, self.decode)(x)
        logits = jnp.reshape(logits, (-1, *self.output_shape))
        return logits

# %%
import math

model = VAE(dim_in=math.prod(input_shape), dim_emb=2, output_shape=input_shape, activation=nnx.tanh, rngs=nnx.Rngs(0, noise=1))
# model = VAE(dim_in=input_shape[-1], dim_emb=2, output_shape=input_shape, activation=nnx.tanh, rngs=nnx.Rngs(0, noise=1))

nnx.display(model)
# Out:
# WARNING:jax._src.xla_bridge:Platform 'METAL' is experimental and not all JAX functionality may be correctly supported!
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1736750841.313594 15359724 mps_client.cc:510] WARNING: JAX Apple GPU support is experimental and not all JAX functionality is correctly supported!
# I0000 00:00:1736750841.322342 15359724 service.cc:145] XLA service 0x175454fd0 initialized for platform METAL (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1736750841.322352 15359724 service.cc:153]   StreamExecutor device (0): Metal, <undefined>
# I0000 00:00:1736750841.323524 15359724 mps_client.cc:406] Using Simple allocator.
# I0000 00:00:1736750841.323530 15359724 mps_client.cc:384] XLA backend will use up to 51539214336 bytes on device 0 for SimpleAllocator.
# Metal device set to: Apple M2 Max
#
# systemMemory: 64.00 GB
# maxCacheSize: 24.00 GB
#
# VAE(
#   encoder=Encoder(
#     layers=[<function Encoder.__init__.<locals>.<lambda> at 0x324a4a840>, Linear(
#       kernel=Param(
#         value=Array(shape=(1024, 512), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(512,), dtype=float32)
#       ),
#       in_features=1024,
#       out_features=512,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x31cd159e0>,
#       bias_init=<function zeros at 0x301a8aca0>,
#       dot_general=<function dot_general at 0x3012f07c0>
#     ), <PjitFunction of <function tanh at 0x30188e520>>, Linear(
#       kernel=Param(
#         value=Array(shape=(512, 128), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(128,), dtype=float32)
#       ),
#       in_features=512,
#       out_features=128,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x31cd159e0>,
#       bias_init=<function zeros at 0x301a8aca0>,
#       dot_general=<function dot_general at 0x3012f07c0>
#     ), <PjitFunction of <function tanh at 0x30188e520>>, Linear(
#       kernel=Param(
#         value=Array(shape=(128, 2), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(2,), dtype=float32)
#       ),
#       in_features=128,
#       out_features=2,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x31cd159e0>,
#       bias_init=<function zeros at 0x301a8aca0>,
#       dot_general=<function dot_general at 0x3012f07c0>
#     )],
#     linear_mean=Linear(
#       kernel=Param(
#         value=Array(shape=(2, 2), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(2,), dtype=float32)
#       ),
#       in_features=2,
#       out_features=2,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x31cd159e0>,
#       bias_init=<function zeros at 0x301a8aca0>,
#       dot_general=<function dot_general at 0x3012f07c0>
#     ),
#     linear_logvar=Linear(
#       kernel=Param(
#         value=Array(shape=(2, 2), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(2,), dtype=float32)
#       ),
#       in_features=2,
#       out_features=2,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x31cd159e0>,
#       bias_init=<function zeros at 0x301a8aca0>,
#       dot_general=<function dot_general at 0x3012f07c0>
#     ),
#     reparameterize=Reparameterization(
#       rngs=RngStream(
#         key=RngKey(
#           value=Array((), dtype=key<fry>) overlaying:
#           [0 1],
#           tag='noise'
#         ),
#         count=RngCount(
#           value=Array(0, dtype=uint32),
#           tag='noise'
#         )
#       )
#     )
#   ),
#   decoder=Decoder(
#     layers=[Linear(
#       kernel=Param(
#         value=Array(shape=(2, 128), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(128,), dtype=float32)
#       ),
#       in_features=2,
#       out_features=128,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x31cd159e0>,
#       bias_init=<function zeros at 0x301a8aca0>,
#       dot_general=<function dot_general at 0x3012f07c0>
#     ), <PjitFunction of <function tanh at 0x30188e520>>, Linear(
#       kernel=Param(
#         value=Array(shape=(128, 512), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(512,), dtype=float32)
#       ),
#       in_features=128,
#       out_features=512,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x31cd159e0>,
#       bias_init=<function zeros at 0x301a8aca0>,
#       dot_general=<function dot_general at 0x3012f07c0>
#     ), <PjitFunction of <function tanh at 0x30188e520>>, Linear(
#       kernel=Param(
#         value=Array(shape=(512, 1024), dtype=float32)
#       ),
#       bias=Param(
#         value=Array(shape=(1024,), dtype=float32)
#       ),
#       in_features=512,
#       out_features=1024,
#       use_bias=True,
#       dtype=None,
#       param_dtype=<class 'jax.numpy.float32'>,
#       precision=None,
#       kernel_init=<function variance_scaling.<locals>.init at 0x31cd159e0>,
#       bias_init=<function zeros at 0x301a8aca0>,
#       dot_general=<function dot_general at 0x3012f07c0>
#     )]
#   ),
#   output_shape=(32, 32, 1)
# )

# %%
import jax.numpy as jnp

model(jnp.ones([1, *input_shape])).shape
# Out:
# (1, 32, 32, 1)

# %% [markdown]
# # Optimizer

# %%
import optax

# lr_schedule = optax.warmup_cosine_decay_schedule(
#     init_value=0.0,
#     peak_value=1e-3,
#     warmup_steps=100,
#     decay_steps=500*len(train_ds),
#     end_value=1e-5
# )
# optimizer = nnx.Optimizer(
#     model,
#     optax.chain(
#         optax.clip(1.0),  # Clip gradients at 1
#         optax.adam(lr_schedule)
#     )
# )

learning_rate=5e-4
optimizer = nnx.Optimizer(model, optax.adam(learning_rate))

metrics =  nnx.MultiMetric(
    loss=nnx.metrics.Average("loss"),
    bce_loss=nnx.metrics.Average("bce_loss"),
    kl_loss=nnx.metrics.Average("kl_loss"),
)
nnx.display(metrics)
# Out:
# MultiMetric(
#   loss=Average(
#     argname='loss',
#     total=MetricState(
#       value=Array(0., dtype=float32)
#     ),
#     count=MetricState(
#       value=Array(0, dtype=int32)
#     )
#   ),
#   bce_loss=Average(
#     argname='bce_loss',
#     total=MetricState(
#       value=Array(0., dtype=float32)
#     ),
#     count=MetricState(
#       value=Array(0, dtype=int32)
#     )
#   ),
#   kl_loss=Average(
#     argname='kl_loss',
#     total=MetricState(
#       value=Array(0., dtype=float32)
#     ),
#     count=MetricState(
#       value=Array(0, dtype=int32)
#     )
#   )
# )

# %% [markdown]
# # Define training steps

# %%
def loss_fn(model: VAE, batch: jax.Array):
    logits = model(batch["image"])
    losses = nnx.pop(model, Loss)
    kl_loss = jnp.mean(jnp.asarray(
        jax.tree_util.tree_leaves(losses)
    ))
    bce_loss = jnp.mean(
        optax.sigmoid_binary_cross_entropy(logits, batch["image"])
    )
    loss = bce_loss + 5e-4 * kl_loss
    return loss, (bce_loss, kl_loss)

# %%
@nnx.jit
def train_step(model: VAE, optimizer: nnx.Optimizer, metrics: nnx.MultiMetric, batch: jax.Array):
    grad_fn = nnx.value_and_grad(loss_fn, has_aux=True)
    (loss, (bce_loss, kl_loss)), grads = grad_fn(model, batch)
    metrics.update(loss=loss, bce_loss=bce_loss, kl_loss=kl_loss)
    optimizer.update(grads)

@nnx.jit
def eval_step(model: VAE, metrics: nnx.MultiMetric, batch: jax.Array):
    (loss, (bce_loss, kl_loss)) = loss_fn(model, batch)
    metrics.update(loss=loss, bce_loss=bce_loss, kl_loss=kl_loss)

# %% [markdown]
# # Train and evaluate the model

# %%
metrics_history = {
    "train_loss":  [],
    "train_bce_loss": [],
    "train_kl_loss": [],
    "test_loss": [],
    "test_bce_loss": [],
    "test_kl_loss": [],
}

num_steps_per_epoch = train_ds.cardinality() // num_epochs

for step, batch in enumerate(train_ds.as_numpy_iterator(), start=1):

    train_step(model, optimizer, metrics, batch)

    if step % num_steps_per_epoch == 0:

        # Log the training metric.
        for metric, value in metrics.compute().items():
            metrics_history[f"train_{metric}"].append(value)
        value = metrics.compute()
        metrics.reset()  # Reset the metric for the test set.

        # Compute the metric on the test set after each training epoch.
        for test_batch in test_ds.as_numpy_iterator():
            eval_step(model, metrics, test_batch)

        # Log the test metric.
        for metric, value in metrics.compute().items():
            metrics_history[f"test_{metric}"].append(value)
        value = metrics.compute()
        metrics.reset()  # Reset the metric for the test set.

        print(
            f"epoch: {step//num_steps_per_epoch}, "
        )

        print(
            f"\ttrain_bce_loss: {metrics_history['train_bce_loss'][-1]:.4f}",
            f"\ttrain_kl_loss: {metrics_history['train_kl_loss'][-1]:.4f}",
        )

        print(
            f"\ttest_bce_loss: {metrics_history['test_bce_loss'][-1]:.4f}",
            f"\ttest_kl_loss: {metrics_history['test_kl_loss'][-1]:.4f}",
        )
# Out:
# epoch: 1,
# 	train_bce_loss: 0.3205 	train_kl_loss: 11.7390
# 	test_bce_loss: 0.2811 	test_kl_loss: 13.7684
# epoch: 2,
# 	train_bce_loss: 0.2724 	train_kl_loss: 13.6631
# 	test_bce_loss: 0.2672 	test_kl_loss: 13.1334
# epoch: 3,
# 	train_bce_loss: 0.2629 	train_kl_loss: 12.5864
# 	test_bce_loss: 0.2663 	test_kl_loss: 12.5697
# epoch: 4,
# 	train_bce_loss: 0.2593 	train_kl_loss: 11.8592
# 	test_bce_loss: 0.2586 	test_kl_loss: 11.2369
# epoch: 5,
# 	train_bce_loss: 0.2564 	train_kl_loss: 11.1699
# 	test_bce_loss: 0.2564 	test_kl_loss: 10.7310
# epoch: 6,
# 	train_bce_loss: 0.2543 	train_kl_loss: 10.8508
# 	test_bce_loss: 0.2547 	test_kl_loss: 10.5614
# epoch: 7,
# 	train_bce_loss: 0.2524 	train_kl_loss: 10.4892
# 	test_bce_loss: 0.2531 	test_kl_loss: 10.1723
# epoch: 8,
# 	train_bce_loss: 0.2511 	train_kl_loss: 10.1679
# 	test_bce_loss: 0.2533 	test_kl_loss: 10.0662
# epoch: 9,
# 	train_bce_loss: 0.2499 	train_kl_loss: 10.0035
# 	test_bce_loss: 0.2523 	test_kl_loss: 9.6063
# epoch: 10,
# 	train_bce_loss: 0.2491 	train_kl_loss: 9.8132
# 	test_bce_loss: 0.2501 	test_kl_loss: 9.6443
# epoch: 11,
# 	train_bce_loss: 0.2481 	train_kl_loss: 9.6251
# 	test_bce_loss: 0.2498 	test_kl_loss: 9.4664
# epoch: 12,
# 	train_bce_loss: 0.2475 	train_kl_loss: 9.5136
# 	test_bce_loss: 0.2487 	test_kl_loss: 9.3913
# epoch: 13,
# 	train_bce_loss: 0.2470 	train_kl_loss: 9.3689
# 	test_bce_loss: 0.2483 	test_kl_loss: 9.2485
# epoch: 14,
# 	train_bce_loss: 0.2466 	train_kl_loss: 9.2933
# 	test_bce_loss: 0.2482 	test_kl_loss: 9.2419
# epoch: 15,
# 	train_bce_loss: 0.2460 	train_kl_loss: 9.2378
# 	test_bce_loss: 0.2474 	test_kl_loss: 9.1557
# epoch: 16,
# 	train_bce_loss: 0.2455 	train_kl_loss: 9.2027
# 	test_bce_loss: 0.2470 	test_kl_loss: 9.1131
# epoch: 17,
# 	train_bce_loss: 0.2452 	train_kl_loss: 9.1578
# 	test_bce_loss: 0.2465 	test_kl_loss: 9.0895
# epoch: 18,
# 	train_bce_loss: 0.2450 	train_kl_loss: 9.0933
# 	test_bce_loss: 0.2461 	test_kl_loss: 9.0925
# epoch: 19,
# 	train_bce_loss: 0.2445 	train_kl_loss: 9.0552
# 	test_bce_loss: 0.2463 	test_kl_loss: 9.0555
# epoch: 20,
# 	train_bce_loss: 0.2442 	train_kl_loss: 9.0270
# 	test_bce_loss: 0.2458 	test_kl_loss: 8.9695
# epoch: 21,
# 	train_bce_loss: 0.2438 	train_kl_loss: 9.0004
# 	test_bce_loss: 0.2455 	test_kl_loss: 8.9517
# epoch: 22,
# 	train_bce_loss: 0.2436 	train_kl_loss: 8.9811
# 	test_bce_loss: 0.2454 	test_kl_loss: 8.8099
# epoch: 23,
# 	train_bce_loss: 0.2434 	train_kl_loss: 8.9136
# 	test_bce_loss: 0.2451 	test_kl_loss: 8.9158
# epoch: 24,
# 	train_bce_loss: 0.2431 	train_kl_loss: 8.9156
# 	test_bce_loss: 0.2446 	test_kl_loss: 8.8924
# epoch: 25,
# 	train_bce_loss: 0.2428 	train_kl_loss: 8.8907
# 	test_bce_loss: 0.2444 	test_kl_loss: 8.8836
# epoch: 26,
# 	train_bce_loss: 0.2427 	train_kl_loss: 8.8671
# 	test_bce_loss: 0.2440 	test_kl_loss: 8.8142
# epoch: 27,
# 	train_bce_loss: 0.2425 	train_kl_loss: 8.8401
# 	test_bce_loss: 0.2440 	test_kl_loss: 8.8244
# epoch: 28,
# 	train_bce_loss: 0.2422 	train_kl_loss: 8.8112
# 	test_bce_loss: 0.2440 	test_kl_loss: 8.7563
# epoch: 29,
# 	train_bce_loss: 0.2421 	train_kl_loss: 8.7669
# 	test_bce_loss: 0.2445 	test_kl_loss: 8.8226
# epoch: 30,
# 	train_bce_loss: 0.2423 	train_kl_loss: 8.7462
# 	test_bce_loss: 0.2438 	test_kl_loss: 8.7184
# epoch: 31,
# 	train_bce_loss: 0.2416 	train_kl_loss: 8.7446
# 	test_bce_loss: 0.2437 	test_kl_loss: 8.7379
# epoch: 32,
# 	train_bce_loss: 0.2416 	train_kl_loss: 8.6882
# 	test_bce_loss: 0.2434 	test_kl_loss: 8.5944
# epoch: 33,
# 	train_bce_loss: 0.2413 	train_kl_loss: 8.6847
# 	test_bce_loss: 0.2435 	test_kl_loss: 8.6091
# epoch: 34,
# 	train_bce_loss: 0.2414 	train_kl_loss: 8.6627
# 	test_bce_loss: 0.2433 	test_kl_loss: 8.6004
# epoch: 35,
# 	train_bce_loss: 0.2412 	train_kl_loss: 8.6355
# 	test_bce_loss: 0.2428 	test_kl_loss: 8.5745
# epoch: 36,
# 	train_bce_loss: 0.2409 	train_kl_loss: 8.6316
# 	test_bce_loss: 0.2429 	test_kl_loss: 8.5939
# epoch: 37,
# 	train_bce_loss: 0.2410 	train_kl_loss: 8.6137
# 	test_bce_loss: 0.2428 	test_kl_loss: 8.5974
# epoch: 38,
# 	train_bce_loss: 0.2409 	train_kl_loss: 8.5768
# 	test_bce_loss: 0.2432 	test_kl_loss: 8.4934
# epoch: 39,
# 	train_bce_loss: 0.2408 	train_kl_loss: 8.5481
# 	test_bce_loss: 0.2431 	test_kl_loss: 8.4828
# epoch: 40,
# 	train_bce_loss: 0.2407 	train_kl_loss: 8.5294
# 	test_bce_loss: 0.2426 	test_kl_loss: 8.4824
# epoch: 41,
# 	train_bce_loss: 0.2405 	train_kl_loss: 8.5285
# 	test_bce_loss: 0.2431 	test_kl_loss: 8.4752
# epoch: 42,
# 	train_bce_loss: 0.2404 	train_kl_loss: 8.4984
# 	test_bce_loss: 0.2425 	test_kl_loss: 8.4463
# epoch: 43,
# 	train_bce_loss: 0.2402 	train_kl_loss: 8.4937
# 	test_bce_loss: 0.2426 	test_kl_loss: 8.4073
# epoch: 44,
# 	train_bce_loss: 0.2400 	train_kl_loss: 8.4546
# 	test_bce_loss: 0.2423 	test_kl_loss: 8.4015
# epoch: 45,
# 	train_bce_loss: 0.2401 	train_kl_loss: 8.4466
# 	test_bce_loss: 0.2435 	test_kl_loss: 8.3568
# epoch: 46,
# 	train_bce_loss: 0.2401 	train_kl_loss: 8.4550
# 	test_bce_loss: 0.2422 	test_kl_loss: 8.4186
# epoch: 47,
# 	train_bce_loss: 0.2396 	train_kl_loss: 8.4240
# 	test_bce_loss: 0.2419 	test_kl_loss: 8.3988
# epoch: 48,
# 	train_bce_loss: 0.2397 	train_kl_loss: 8.4207
# 	test_bce_loss: 0.2420 	test_kl_loss: 8.4110
# epoch: 49,
# 	train_bce_loss: 0.2395 	train_kl_loss: 8.4058
# 	test_bce_loss: 0.2422 	test_kl_loss: 8.3448
# epoch: 50,
# 	train_bce_loss: 0.2398 	train_kl_loss: 8.3838
# 	test_bce_loss: 0.2426 	test_kl_loss: 8.3231

# %%
import matplotlib.pyplot as plt  # Visualization

# Plot loss and accuracy in subplots
fig = plt.figure(figsize=(5.5, 5))
plt.title('Loss')
for dataset in ('train', 'test'):
    plt.plot(metrics_history[f'{dataset}_loss'], label=f'{dataset}_loss')
fig.legend()
plt.show()

# %% [markdown]
# # Reconstruction

# %%
test_examples = test_batch['image']
display(test_examples)

# %%
reconstructions = nnx.sigmoid(model(test_examples))
display(reconstructions)

# %% [markdown]
# # Reconstruction

# %%
import numpy as np


def get_samples(ds, num_samples=10):
    example_images = []; example_labels = []
    for i, samples in enumerate(test_ds.as_numpy_iterator()):
        example_images.append(samples["image"])
        example_labels.append(samples["label"])

        if i*batch_size >= n_to_predict:
            break
    return np.vstack(example_images)[:n_to_predict], np.hstack(example_labels)[:n_to_predict]

n_to_predict = 5_000
example_images, example_labels = get_samples(test_ds, num_samples=n_to_predict)

embeddings = model.encode(example_images)

# %%
embeddings = model.encode(example_images)

figsize = 6
plt.figure(figsize=(figsize, figsize*0.8))
plt.scatter(
    embeddings[:, 0],
    embeddings[:, 1],
    cmap="rainbow",
    c=example_labels,
    alpha=0.8,
    s=3,
)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Generating new images

# %%
mins, maxs = np.min(embeddings, axis=0), np.max(embeddings, axis=0)

# Sample some points in the latent space
grid_width, grid_height = (5, 2)
samples = np.random.uniform(
    mins, maxs, size=(grid_width * grid_height, dim_latent)
)

# %%
reconstructions = model.generate(samples).reshape(-1, *input_shape)
display(reconstructions)

# %%
# Draw a plot of...
figsize = 5.5
plt.figure(figsize=(figsize, figsize))

# ... the original embeddings ...
plt.scatter(embeddings[:, 0], embeddings[:, 1], c=example_labels, cmap="rainbow", alpha=0.5, s=2)

# ... and the newly generated points in the latent space
plt.scatter(samples[:, 0], samples[:, 1], c="black", alpha=1, s=40)
plt.show()

# Add underneath a grid of the decoded images
fig = plt.figure(figsize=(figsize, grid_height))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_width * grid_height):
    ax = fig.add_subplot(grid_height, grid_width, i + 1)
    ax.axis("off")
    ax.text(
        0.5,
        -0.35,
        str(np.round(samples[i, :], 1)),
        fontsize=10,
        ha="center",
        transform=ax.transAxes,
    )
    ax.imshow(reconstructions[i, :, :], cmap="Greys")

# %% [markdown]
# # Latent space

# %%
from scipy.stats import norm

p = norm.cdf(embeddings)
# p_sample = norm.cdf(z_samples)

plt.figure(figsize=(7, 6))
plt.scatter(p[:, 0],
            p[:, 1],
            cmap="rainbow",
            c=example_labels,
            alpha=0.8,
            s=3)
plt.colorbar()
plt.show()

# %%
sample_size = 14

x = norm.ppf(np.linspace(0.01, 0.99, sample_size))
y = norm.ppf(np.linspace(0.99, 0.01, sample_size))

xv, yv = np.meshgrid(x, y)
xv = xv.flatten()
yv = yv.flatten()
grid = np.array(list(zip(xv, yv)))

generated_imgs = model.generate(grid)

# %%
fig = plt.figure(figsize=(12, 12))
fig.subplots_adjust(hspace=0.2, wspace=0.2)
for i in range(sample_size**2):
    ax = fig.add_subplot(sample_size, sample_size, i + 1)
    ax.axis("off")
    ax.imshow(generated_imgs[i], cmap="gray")
